# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# -----------------------------------------------------
# AttributeError      Traceback (most recent call last)
# <ipython-input-1-59309fb5a3f1> in <module>
# ----> 1 import tensorflow as tf
#       2 print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
#
# /opt/conda/lib/python3.6/site-packages/tensorflow/__init__.py in <module>
#      99
#     100 # We still need all the names that are toplevel on tensorflow_core
# --> 101 from tensorflow_core import *
#     102
#     103 # These should not be visible in the main tf module.
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/__init__.py in <module>
#      44 from . _api.v2 import autograph
#      45 from . _api.v2 import bitwise
# ---> 46 from . _api.v2 import compat
#      47 from . _api.v2 import config
#      48 from . _api.v2 import data
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/__init__.py in <module>
#      37 import sys as _sys
#      38
# ---> 39 from . import v1
#      40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/__init__.py in <module>
#      30 from . import autograph
#      31 from . import bitwise
# ---> 32 from . import compat
#      33 from . import config
#      34 from . import data
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/compat/__init__.py in <module>
#      37 import sys as _sys
#      38
# ---> 39 from . import v1
#      40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/compat/v1/__init__.py in <module>
#      27
#      28 from . import compat
# ---> 29 from tensorflow._api.v2.compat.v1 import app
#      30 from tensorflow._api.v2.compat.v1 import audio
#      31 from tensorflow._api.v2.compat.v1 import autograph
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/__init__.py in <module>
#      37 import sys as _sys
#      38
# ---> 39 from . import v1
#      40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/__init__.py in <module>
#      30 from . import autograph
#      31 from . import bitwise
# ---> 32 from . import compat
#      33 from . import config
#      34 from . import data
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/compat/__init__.py in <module>
#      38
#      39 from . import v1
# ---> 40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      42 from tensorflow.python.compat.compat import forward_compatible
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v1/compat/v2/__init__.py in <module>
#      28
#      29 from . import compat
# ---> 30 from tensorflow._api.v2.compat.v2 import audio
#      31 from tensorflow._api.v2.compat.v2 import autodiff
#      32 from tensorflow._api.v2.compat.v2 import autograph
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v2/__init__.py in <module>
#      31 from . import autograph
#      32 from . import bitwise
# ---> 33 from . import compat
#      34 from . import config
#      35 from . import data
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v2/compat/__init__.py in <module>
#      38
#      39 from . import v1
# ---> 40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#      42 from tensorflow.python.compat.compat import forward_compatible
#
# /opt/conda/lib/python3.6/site-packages/tensorflow_core/_api/v2/compat/v2/compat/v2/__init__.py in <module>
#     318 _current_module = _sys.modules[__name__]
#     319 try:
# --> 320   from tensorboard.summary._tf import summary
#     321   _current_module.__path__ = (
#     322       [_module_util.get_parent_dir(summary)] + _current_module.__path__)
#
# /opt/conda/lib/python3.6/site-packages/tensorboard/summary/__init__.py in <module>
#      29 # Load the V2 summary API if accessible.
#      30 try:
# ---> 31   from tensorboard.summary import v2
#      32   from tensorboard.summary.v2 import *
#      33 except ImportError:
#
# /opt/conda/lib/python3.6/site-packages/tensorboard/summary/v2.py in <module>
#      22
#      23 # pylint: disable=unused-import
# ---> 24 from tensorboard.plugins.audio.summary_v2 import audio
#      25 from tensorboard.plugins.histogram.summary_v2 import histogram
#      26 from tensorboard.plugins.image.summary_v2 import image
#
# /opt/conda/lib/python3.6/site-packages/tensorboard/plugins/audio/summary_v2.py in <module>
#      28 import functools
#      29
# ---> 30 from tensorboard.compat import tf2 as tf
#      31 from tensorboard.plugins.audio import metadata
#      32 from tensorboard.util import lazy_tensor_creator
#
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/__init__.py in <module>
#      26 import importlib as _importlib
#      27
# ---> 28 import tensorboard.lazy as _lazy
#      29
#      30
#
# AttributeError: module 'tensorboard' has no attribute 'lazy'
